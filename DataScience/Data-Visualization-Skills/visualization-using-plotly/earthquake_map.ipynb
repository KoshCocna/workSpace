# %%
import pandas as pd
import plotly.express as px

# %%
data=pd.read_csv('https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_month.csv')

# %%
data.head()
# Out:
#                        time   latitude   longitude  depth   mag magType   nst  \
# 0  2024-03-18T04:10:21.700Z  19.271833 -155.382004  28.84  2.05      ml  50.0
# 1  2024-03-18T04:09:31.270Z  38.777832 -122.760834   4.43  0.79      md  11.0
# 2  2024-03-18T03:52:09.958Z  61.949400 -150.288800   2.90  1.60      ml   NaN
# 3  2024-03-18T03:18:48.539Z  58.969300 -153.464300  59.20  2.00      ml   NaN
# 4  2024-03-18T03:12:29.728Z  61.748900 -149.449300   0.00  1.40      ml   NaN
#
#      gap     dmin   rms  ...                   updated  \
# 0  128.0  0.06134  0.16  ...  2024-03-18T04:13:01.970Z
# 1  211.0  0.01960  0.04  ...  2024-03-18T04:11:06.903Z
# 2    NaN      NaN  0.39  ...  2024-03-18T03:54:21.893Z
# 3    NaN      NaN  0.43  ...  2024-03-18T03:20:42.351Z
# 4    NaN      NaN  0.65  ...  2024-03-18T03:14:48.954Z
#
#                                      place        type horizontalError  \
# 0               12 km NE of Pāhala, Hawaii  earthquake            0.43
# 1                0 km W of The Geysers, CA  earthquake            2.05
# 2              26 km NNW of Willow, Alaska  earthquake             NaN
# 3  87 km SE of Pope-Vannoy Landing, Alaska  earthquake             NaN
# 4              11 km W of Fishhook, Alaska  earthquake             NaN
#
#   depthError  magError  magNst     status  locationSource magSource
# 0       0.56      0.27     9.0  automatic              hv        hv
# 1       2.48      0.06    12.0  automatic              nc        nc
# 2       0.50       NaN     NaN  automatic              ak        ak
# 3       1.80       NaN     NaN  automatic              ak        ak
# 4       0.60       NaN     NaN  automatic              ak        ak
#
# [5 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9978 entries, 0 to 9977
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             9978 non-null   object
#  1   latitude         9978 non-null   float64
#  2   longitude        9978 non-null   float64
#  3   depth            9978 non-null   float64
#  4   mag              9978 non-null   float64
#  5   magType          9978 non-null   object
#  6   nst              7902 non-null   float64
#  7   gap              7902 non-null   float64
#  8   dmin             7236 non-null   float64
#  9   rms              9978 non-null   float64
#  10  net              9978 non-null   object
#  11  id               9978 non-null   object
#  12  updated          9978 non-null   object
#  13  place            9978 non-null   object
#  14  type             9978 non-null   object
#  15  horizontalError  7277 non-null   float64
#  16  depthError       9978 non-null   float64
#  17  magError         7887 non-null   float64
#  18  magNst           7902 non-null   float64
#  19  status           9978 non-null   object
#  20  locationSource   9978 non-null   object
#  21  magSource        9978 non-null   object
# dtypes: float64(12), object(10)
# memory usage: 1.7+ MB

# %%
data=data.dropna(subset=['mag'])
data.shape
# Out:
# (9978, 22)

# %%
data=data[data.mag>=0]
data.shape
# Out:
# (9482, 22)

# %%
fig=px.scatter_geo(
    data,
    lat='latitude',
    lon='longitude',
    color='mag',
    #hover_name='place',
    #color_continuous_scale='reds',
    title='Earthquakes Around the World'
)
fig.update_layout(geo=dict(bgcolor='black'))
fig.show()
