# %%
import pandas as pd
import seaborn as sns
import warnings
from matplotlib import pyplot as plt

# %%
warnings.filterwarnings('ignore')

# %%
raw_data=pd.read_csv('Stock_TLKM_2005-2024.csv')
raw_data.head(3)
# Out:
#          Date   Open   High    Low  Close   Adj Close       Volume
# 0  2005-01-26  965.0  975.0  965.0  970.0  548.346130   84725000.0
# 1  2005-01-27  970.0  970.0  960.0  960.0  542.692932  134222500.0
# 2  2005-01-28  965.0  965.0  955.0  960.0  542.692932  100760000.0

# %%
raw_data.insert(7,'year',raw_data['Date'].str[:4])

# %%
raw_data
# Out:
#             Date    Open    High     Low   Close    Adj Close       Volume  \
# 0     2005-01-26   965.0   975.0   965.0   970.0   548.346130   84725000.0
# 1     2005-01-27   970.0   970.0   960.0   960.0   542.692932  134222500.0
# 2     2005-01-28   965.0   965.0   955.0   960.0   542.692932  100760000.0
# 3     2005-01-31   960.0   965.0   950.0   960.0   542.692932  137322500.0
# 4     2005-02-01   965.0   975.0   960.0   965.0   545.519531   69960000.0
# ...          ...     ...     ...     ...     ...          ...          ...
# 4700  2024-01-24  3950.0  3980.0  3930.0  3970.0  3970.000000   38732000.0
# 4701  2024-01-25  3980.0  4000.0  3960.0  3980.0  3980.000000   58541300.0
# 4702  2024-01-26  3940.0  3990.0  3930.0  3980.0  3980.000000   65272600.0
# 4703  2024-01-29  4000.0  4010.0  3970.0  4010.0  4010.000000   59150000.0
# 4704  2024-01-30  4000.0  4020.0  3980.0  4000.0  4000.000000   66906900.0
#
#       year
# 0     2005
# 1     2005
# 2     2005
# 3     2005
# ...

# %%
data_by_year=raw_data.groupby('year')

# %%
highest_by_Close_stock=pd.DataFrame(columns=raw_data.columns)

# %%
for y, data in data_by_year:
    highest=data.nlargest(1, 'Close')
    highest_by_Close_stock=pd.concat(objs=[highest_by_Close_stock,pd.DataFrame(highest)])
highest_by_Close_stock.insert(8,'hue',0)
highest_by_Close_stock
# Out:
#             Date    Open    High     Low   Close    Adj Close       Volume  \
# 217   2005-12-13  1230.0  1240.0  1200.0  1230.0   715.061340  142257500.0
# 473   2006-12-06  2110.0  2170.0  2100.0  2110.0  1264.026245  189230000.0
# 686   2007-10-11  2530.0  2550.0  2480.0  2530.0  1557.944092   67147500.0
# 741   2008-01-08  2040.0  2060.0  2030.0  2050.0  1268.217651  157245000.0
# 1213  2009-12-17  2020.0  2070.0  1990.0  2020.0  1374.227661  146767500.0
# 1405  2010-10-05  1960.0  1960.0  1880.0  1960.0  1379.041992  122117500.0
# 1465  2011-01-03  1600.0  1610.0  1580.0  1600.0  1129.573486   34922500.0
# 1909  2012-10-16  1970.0  1970.0  1920.0  1970.0  1459.184326   95815000.0
# 2059  2013-05-29  2460.0  2500.0  2460.0  2480.0  1836.942749  111012500.0
# 2375  2014-09-19  2945.0  3010.0  2870.0  2945.0  2316.452637  115537500.0
# 2686  2015-12-22  3100.0  3135.0  3100.0  3135.0  2478.622314   68929200.0
# ...

# %%
lowest_by_Close_stock=pd.DataFrame(columns=raw_data.columns)

# %%
for x, data in data_by_year:
    lowest=data.nsmallest(1, 'Close')
    lowest_by_Close_stock=pd.concat(objs=[lowest_by_Close_stock,pd.DataFrame(lowest)])
lowest_by_Close_stock.insert(8,'hue',1)
lowest_by_Close_stock
# Out:
#             Date    Open    High     Low   Close    Adj Close       Volume  \
# 64    2005-05-03   820.0   845.0   820.0   835.0   472.029846  136657500.0
# 262   2006-02-14  1210.0  1220.0  1190.0  1190.0   691.807312  159977500.0
# 531   2007-02-28  1780.0  1800.0  1710.0  1780.0  1071.500366  398190000.0
# 933   2008-10-28  1000.0  1060.0   970.0  1000.0   654.502197  364310000.0
# 996   2009-02-03  1170.0  1200.0  1150.0  1170.0   765.767639  108997500.0
# 1316  2010-05-24  1420.0  1510.0  1420.0  1420.0   966.041199   98112500.0
# 1519  2011-03-22  1320.0  1360.0  1320.0  1320.0   931.898071  124460000.0
# 1733  2012-02-01  1350.0  1370.0  1340.0  1350.0   992.529663  145167500.0
# 1958  2013-01-02  1790.0  1830.0  1770.0  1790.0  1325.857910   60222500.0
# 2205  2014-01-07  2085.0  2085.0  2060.0  2070.0  1541.597656   73637100.0
# 2626  2015-09-28  2620.0  2645.0  2600.0  2600.0  2055.635986   20695500.0
# ...

# %%
data1=pd.concat(objs=[highest_by_Close_stock,lowest_by_Close_stock])
data1.tail(3)
# Out:
#             Date    Open    High     Low   Close    Adj Close       Volume  \
# 4426  2022-12-06  3640.0  3720.0  3580.0  3600.0  3454.613037  416468700.0
# 4641  2023-10-30  3500.0  3500.0  3390.0  3420.0  3420.000000   82945500.0
# 4687  2024-01-05  3950.0  3970.0  3880.0  3890.0  3890.000000   69268000.0
#
#       year  hue
# 4426  2022    1
# 4641  2023    1
# 4687  2024    1

# %%
fig, ax = plt.subplots(figsize=(10, 6))
#sns.set(font_scale = 0.6)
g=sns.lineplot(
    data=data1,
    x='year',
    y='Close',
    hue='hue',
    ax=ax
)
plt.legend(title='max&min', fontsize=16)
#plt.xlabel('Year', fontsize=16);
plt.ylabel('Stock Price', fontsize=16);
plt.title('Tele-Company Stock Price', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=8)
