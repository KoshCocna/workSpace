# %%
import pandas as pd
import seaborn as sns
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
general=pd.read_csv('23_24_premier_league_0408_general.csv')
opponent_stats=pd.read_csv('23_24_premier_league_0408_opponent_stats.csv')
squad_advanced_goalkeeping=pd.read_csv('23_24_premier_league_0408_Squad Advanced Goalkeeping.csv')
squad_defensive_actions=pd.read_csv('23_24_premier_league_0408_Squad Defensive Actions.csv')
squad_miscellaneous_stats=pd.read_csv('23_24_premier_league_0408_Squad Miscellaneous Stats.csv')
squad_shooting_opponent=pd.read_csv('23_24_premier_league_0408_Squad Shooting_opponent.csv')
squad_shooting=pd.read_csv('23_24_premier_league_0408_Squad Shooting.csv')
squad_goalkeeping_opponent=pd.read_csv('23_24_premier_league_0408_Squad_Goalkeeping_opponent.csv')
squad_goalkeeping=pd.read_csv('23_24_premier_league_0408_Squad_Goalkeeping.csv')
squad_stats=pd.read_csv('23_24_premier_league_0408_Squad_stats.csv')

# %%
general.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 28 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   league_position  20 non-null     int64
#  1   squad            20 non-null     object
#  2   Home_MP          20 non-null     int64
#  3   Home_W           20 non-null     int64
#  4   Home_D           20 non-null     int64
#  5   Home_L           20 non-null     int64
#  6   Home_GF          20 non-null     int64
#  7   Home_GA          20 non-null     int64
#  8   Home_GD          20 non-null     int64
#  9   Home_Pts         20 non-null     int64
#  10  Home_Pts/MP      20 non-null     float64
#  11  Home_xG          20 non-null     float64
#  12  Home_xGA         20 non-null     float64
#  13  Home_xGD         20 non-null     float64
#  14  Home_xGD/90      20 non-null     float64
#  15  Away_MP          20 non-null     int64
#  16  Away_W           20 non-null     int64
# ...

# %%
general.nunique()
# Out:
# league_position    20
# squad              20
# Home_MP             2
# Home_W             11
# Home_D              8
# Home_L             11
# Home_GF            14
# Home_GA            15
# Home_GD            15
# Home_Pts           17
# Home_Pts/MP        19
# Home_xG            17
# Home_xGA           18
# Home_xGD           19
# Home_xGD/90        19
# Away_MP             2
# Away_W              9
# Away_D              5
# Away_L              9
# Away_GF            15
# Away_GA            13
# Away_GD            14
# Away_Pts           13
# Away_Pts/MP        16
# Away_xG            19
# Away_xGA           20
# Away_xGD           20
# Away_xGD/90        18
# dtype: int64

# %%
general.head(3)
# Out:
#    league_position            squad  Home_MP  Home_W  Home_D  Home_L  Home_GF  \
# 0                1          Arsenal       15      12       2       1       38
# 1                2        Liverpool       16      13       3       0       43
# 2                3  Manchester City       16      11       5       0       38
#
#    Home_GA  Home_GD  Home_Pts  ...  Away_L  Away_GF  Away_GA  Away_GD  \
# 0       13       25        38  ...       3       37       11       26
# 1       14       29        42  ...       2       29       16       13
# 2       13       25        38  ...       3       33       18       15
#
#    Away_Pts  Away_Pts/MP  Away_xG  Away_xGA  Away_xGD  Away_xGD/90
# 0        33         2.06     28.9      11.5      17.5         1.09
# 1        29         1.93     26.5      22.3       4.2         0.28
# 2        32         2.13     32.0      17.3      14.7         0.98
#
# [3 rows x 28 columns]

# %%
general.drop('league_position', axis=1, inplace=True)

# %%
general.set_index('squad',inplace=True)

# %%
general
# Out:
#                  Home_MP  Home_W  Home_D  Home_L  Home_GF  Home_GA  Home_GD  \
# squad
# Arsenal               15      12       2       1       38       13       25
# Liverpool             16      13       3       0       43       14       29
# Manchester City       16      11       5       0       38       13       25
# Tottenham             16      12       0       4       34       21       13
# Aston Villa           16      11       2       3       40       22       18
# Manchester Utd        15       8       2       5       23       22        1
# West Ham              16       6       7       3       26       23        3
# Newcastle Utd         16      10       3       3       39       20       19
# Chelsea               15       7       4       4       29       25        4
# Brighton              15       7       6       2       28       19        9
# Wolves                15       7       3       5       23       23        0
# ...

# %%
sns.heatmap(general)
# Out:
# <Axes: ylabel='squad'>

# %%
squad_stats
# Out:
#               Squad  Num_of_players   Age  Possesion  Playing Time_MP  \
# 0           Arsenal              25  25.7       59.8               31
# 1       Aston Villa              30  27.6       54.7               32
# 2       Bournemouth              28  26.5       45.2               31
# 3         Brentford              28  27.4       43.9               32
# 4          Brighton              28  26.7       61.5               31
# 5           Burnley              31  25.2       46.8               32
# 6           Chelsea              30  25.0       58.8               30
# 7    Crystal Palace              26  27.7       41.5               31
# 8           Everton              25  27.6       40.5               31
# 9            Fulham              25  29.2       51.5               32
# 10        Liverpool              29  27.0       60.7               31
# 11       Luton Town              26  27.5       42.3               32
# ...

# %%
squad_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Squad                    20 non-null     object
#  1   Num_of_players           20 non-null     int64
#  2   Age                      20 non-null     float64
#  3   Possesion                20 non-null     float64
#  4   Playing Time_MP          20 non-null     int64
#  5   Playing Time_Starts      20 non-null     int64
#  6   Playing Time_Min         20 non-null     int64
#  7   Playing Time_90s         20 non-null     float64
#  8   Performance_Gls          20 non-null     int64
#  9   Performance_Ast          20 non-null     int64
#  10  Performance_G+A          20 non-null     int64
#  11  Performance_G-PK         20 non-null     int64
#  12  Performance_PK           20 non-null     int64
#  13  Performance_PKatt        20 non-null     int64
# ...

# %%
sns.scatterplot(
    data=squad_stats,
    x='Age',
    y='Possesion',
)
# Out:
# <Axes: xlabel='Age', ylabel='Possesion'>

# %%
squad_advanced_goalkeeping
# Out:
#               Squad  Num_of_players  Mins_played_diveded_90  Goals_GA  \
# 0           Arsenal               2                    31.0        24
# 1       Aston Villa               2                    32.0        49
# 2       Bournemouth               2                    31.0        55
# 3         Brentford               2                    32.0        58
# 4          Brighton               2                    31.0        49
# 5           Burnley               2                    32.0        67
# 6           Chelsea               2                    30.0        52
# 7    Crystal Palace               3                    31.0        54
# 8           Everton               1                    31.0        42
# 9            Fulham               1                    32.0        51
# 10        Liverpool               2                    31.0        30
# 11       Luton Town               1                    32.0        65
# ...

# %%
squad_advanced_goalkeeping.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Squad                   20 non-null     object
#  1   Num_of_players          20 non-null     int64
#  2   Mins_played_diveded_90  20 non-null     float64
#  3   Goals_GA                20 non-null     int64
#  4   Goals_PKA               20 non-null     int64
#  5   Goals_FK                20 non-null     int64
#  6   Goals_CK                20 non-null     int64
#  7   Goals_OG                20 non-null     int64
#  8   Expected_PSxG           20 non-null     float64
#  9   Expected_PSxG/SoT       20 non-null     float64
#  10  Expected_PSxG+/-        20 non-null     float64
#  11  Expected_/90            20 non-null     float64
#  12  Launched_Cmp            20 non-null     int64
#  13  Launched_Att            20 non-null     int64
# ...

# %%
# 스포츠 관련 약어들이 너무 많아 다루기에 어려움이 있음!
